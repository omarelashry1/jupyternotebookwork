# %%
pip install biopython
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.7' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from Bio import SeqIO

# %%
delt = open('gisaid_hcov-19_2023_02_10_19.fasta' , 'rt' )
seqobj = [seq for seq in SeqIO.parse(delt, 'fasta')]
delt.close()

# %%
omic = open('gisaid_hcov-19_2023_02_16_21.fasta' , 'rt' )
seqobj1 = [seq for seq in SeqIO.parse(omic, 'fasta')]
omic.close()

# %%
for x in seqobj:
  x.seq.upper()

for x in seqobj1:
  x.seq.upper()

# %%
letters = ['A', 'C','G', 'T']
for x in seqobj:
  filter(letters,x)

for x in seqobj1:
  filter(letters,x)

# %%
# !mkdir SARS_CoV_2_Variants

# %%
cd SARS_CoV_2_Variants
# Out:
# c:\Users\omare\Desktop\CS4440 Assignment 1\SARS_CoV_2_Variants

# %%
# !mkdir Omicron
# !mkdir Delta

# %%
cd Delta
# Out:
# c:\Users\omare\Desktop\CS4440 Assignment 1\SARS_CoV_2_Variants\Delta

# %%
def batch_iterator(iterator, batch_size):
    """Returns lists of length batch_size.

    This can be used on any iterator, for example to batch up
    SeqRecord objects from Bio.SeqIO.parse(...), or to batch
    Alignment objects from Bio.Align.parse(...), or simply
    lines from a file handle.

    This is a generator function, and it returns lists of the
    entries from the supplied iterator.  Each list will have
    batch_size entries, although the final list may be shorter.
    """
    batch = []
    for entry in iterator:
        batch.append(entry)
        if len(batch) == batch_size:
            yield batch
            batch = []
    if batch:
        yield batch
for i, batch in enumerate(batch_iterator(seqobj, 1)):
    filename = "Delta_%i.fasta" % (i + 1)
    with open(filename, "w") as handle:
        count = SeqIO.write(batch, handle, "fasta")
    print("Wrote %i records to %s" % (count, filename))
# Out:
# Wrote 1 records to Delta_1.fasta
# Wrote 1 records to Delta_2.fasta
# Wrote 1 records to Delta_3.fasta
# Wrote 1 records to Delta_4.fasta
# Wrote 1 records to Delta_5.fasta
# Wrote 1 records to Delta_6.fasta
# Wrote 1 records to Delta_7.fasta
# Wrote 1 records to Delta_8.fasta
# Wrote 1 records to Delta_9.fasta
# Wrote 1 records to Delta_10.fasta
# Wrote 1 records to Delta_11.fasta
# Wrote 1 records to Delta_12.fasta
# Wrote 1 records to Delta_13.fasta
# Wrote 1 records to Delta_14.fasta
# Wrote 1 records to Delta_15.fasta
# Wrote 1 records to Delta_16.fasta
# Wrote 1 records to Delta_17.fasta
# Wrote 1 records to Delta_18.fasta
# Wrote 1 records to Delta_19.fasta
# Wrote 1 records to Delta_20.fasta
# Wrote 1 records to Delta_21.fasta
# Wrote 1 records to Delta_22.fasta
# Wrote 1 records to Delta_23.fasta
# Wrote 1 records to Delta_24.fasta
# Wrote 1 records to Delta_25.fasta
# Wrote 1 records to Delta_26.fasta
# Wrote 1 records to Delta_27.fasta
# Wrote 1 records to Delta_28.fasta
# ...

# %%
cd ..
# Out:
# c:\Users\omare\Desktop\CS4440 Assignment 1\SARS_CoV_2_Variants

# %%
cd Omicron
# Out:
# c:\Users\omare\Desktop\CS4440 Assignment 1\SARS_CoV_2_Variants\Omicron

# %%
def batch_iterator(iterator, batch_size):
    """Returns lists of length batch_size.

    This can be used on any iterator, for example to batch up
    SeqRecord objects from Bio.SeqIO.parse(...), or to batch
    Alignment objects from Bio.Align.parse(...), or simply
    lines from a file handle.

    This is a generator function, and it returns lists of the
    entries from the supplied iterator.  Each list will have
    batch_size entries, although the final list may be shorter.
    """
    batch = []
    for entry in iterator:
        batch.append(entry)
        if len(batch) == batch_size:
            yield batch
            batch = []
    if batch:
        yield batch
for i, batch in enumerate(batch_iterator(seqobj1, 1)):
    filename = "Omicron_%i.fasta" % (i + 1)
    with open(filename, "w") as handle:
        count = SeqIO.write(batch, handle, "fasta")
    print("Wrote %i records to %s" % (count, filename))
# Out:
# Wrote 1 records to Omicron_1.fasta
# Wrote 1 records to Omicron_2.fasta
# Wrote 1 records to Omicron_3.fasta
# Wrote 1 records to Omicron_4.fasta
# Wrote 1 records to Omicron_5.fasta
# Wrote 1 records to Omicron_6.fasta
# Wrote 1 records to Omicron_7.fasta
# Wrote 1 records to Omicron_8.fasta
# Wrote 1 records to Omicron_9.fasta
# Wrote 1 records to Omicron_10.fasta
# Wrote 1 records to Omicron_11.fasta
# Wrote 1 records to Omicron_12.fasta
# Wrote 1 records to Omicron_13.fasta
# Wrote 1 records to Omicron_14.fasta
# Wrote 1 records to Omicron_15.fasta
# Wrote 1 records to Omicron_16.fasta
# Wrote 1 records to Omicron_17.fasta
# Wrote 1 records to Omicron_18.fasta
# Wrote 1 records to Omicron_19.fasta
# Wrote 1 records to Omicron_20.fasta
# Wrote 1 records to Omicron_21.fasta
# Wrote 1 records to Omicron_22.fasta
# Wrote 1 records to Omicron_23.fasta
# Wrote 1 records to Omicron_24.fasta
# Wrote 1 records to Omicron_25.fasta
# Wrote 1 records to Omicron_26.fasta
# ...

# %% [markdown]
# Step 4 & 5:

# %%
def cgr(seq, order, k):
 ln = len(seq)
 pw = 2**k
 out = [[0 for i in range(pw)] for j in range(pw)]
 x = 2**(k-1)
 y = 2**(k-1)
 for i in range(0,ln):
   x=x//2
   y=y//2
   if(seq[i] == order[2] or seq[i] == order[3]):
      x = x + (2**(k-1))
   if(seq[i] == order[0] or seq[i] == order[3]):
      y = y + (2**(k-1))
   if(i>=k-1):
      out[y][x] = out[y][x]+1
 return out

# %%
cd Delta
# Out:
# c:\Users\omare\Desktop\CS4440 Assignment 1\SARS_CoV_2_Variants\Delta

# %%
import os, glob
path = 'c:\\Users\\omare\\Desktop\\CS4440 Assignment 1\\SARS_CoV_2_Variants\\Delta'
ar = []
for filename in glob.glob(os.path.join(path, '*.fasta')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f:
     seqobjr =SeqIO.parse(filename, 'fasta')
     seqr = [seq for seq in seqobjr]
     for x in seqr :
        res = cgr(x.seq, order="ACGT", k=7)
        ar.append(res)

# %%
len(ar)
# Out:
# 159

# %%
path = 'c:\\Users\\omare\\Desktop\\CS4440 Assignment 1\\SARS_CoV_2_Variants\\Omicron'
arOmic = []
for filename in glob.glob(os.path.join(path, '*.fasta')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f:
     seqobjr =SeqIO.parse(filename, 'fasta')
     seqr = [seq for seq in seqobjr]
     for x in seqr :
        res = cgr(x.seq, order="ACGT", k=7)
        arOmic.append(res)

# %%
ARR = ar + arOmic

# %%
len(ARR)
# Out:
# 731

# %% [markdown]
# Step 6:

# %%
concat_lst = []

for temp in ARR:
    for elem in temp:
        concat_lst.append(elem)

# %%
pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn import metrics
D = metrics.pairwise_distances(concat_lst)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[58], line 2
#       1 from sklearn import metrics
# ----> 2 D = metrics.pairwise_distances(concat_lst)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
# ...

# %% [markdown]
# Step 7:

# %%
import sklearn.manifold
embedding = sklearn.manifold.MDS(n_components=3, normalized_stress = 'auto')
pwdis_transformed = embedding.fit_transform(D)
